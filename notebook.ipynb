# %%
import annualReturns

# calls the method from annual return
ARBTC = annualReturns.dataFrame()
# Out:
# Months with a return above 5%:
#  Counter({'Oct': 2, 'Feb': 1, 'March': 1})
# Bitcoin was positive while the S&P was negative 1 times since inception
# Bitcoin was negative while the S&P was positive 1 times since inception
# Bitcoin was positive while the S&P was positive 6 times since inception
# Bitcoin was negative while the S&P was negative 1 times since inception
# Bitcoin was positive while the S&P was negative 1 times since inception
# Bitcoin was negative while the S&P was positive 1 times since inception
# Bitcoin was positive while the S&P was positive 6 times since inception
# Bitcoin was negative while the S&P was negative 1 times since inception

# %%
import monthlyReturnBTC
print("        "
      "Monthly Percent Change of Assets\n")
MRBTC = monthlyReturnBTC.merge_and_plot_data()
# Out:
#         Monthly Percent Change of Assets
